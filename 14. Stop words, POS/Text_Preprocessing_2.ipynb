# %%
        corpus = '''The IPL is a Twenty20 cricket league, the most popular in the world,
        featuring ten city-based franchises battling it out annually in India.
        Founded in 2007, it quickly rose to fame with its fast-paced action,
        star-studded players, and glamorous atmosphere.Matches are short and explosive,
        lasting just three hours, making them perfect for modern attention spans.
        Global cricket icons like Virat Kohli, Rohit Sharma, and David Warner clash,
        showcasing their skills in a condensed format. Beyond the on-field action,
        the IPL thrives on its entertainment value. Cheerleaders, Bollywood celebrities,
        and extravagant opening ceremonies add to the spectacle. It's not just cricket;
        it's a cultural phenomenon, attracting millions of viewers and fueling a
        multi-billion dollar industry. The economic impact is undeniable.
        The IPL contributes significantly to India's GDP, generates jobs, and fuels
        the growth of other sports leagues. It's a breeding ground for young talent,
        providing them with a platform to shine and potentially reach the international
        stage. However, the IPL isn't without its challenges. Concerns about match-fixing,
        player fatigue, and franchise ownership remain. Despite these, the IPL's
        popularity shows no signs of waning. Its ability to blend sport, entertainment,
        and commerce makes it a powerful force, not just in India, but on the global sporting stage.'''

# %%
# Tokenization
import nltk
nltk.download('punkt')
sentences = nltk.sent_tokenize(corpus)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
for sentence in sentences:
    print(sentence)
# Out:
# The IPL is a Twenty20 cricket league, the most popular in the world,
# featuring ten city-based franchises battling it out annually in India.
# Founded in 2007, it quickly rose to fame with its fast-paced action,
# star-studded players, and glamorous atmosphere.Matches are short and explosive,
# lasting just three hours, making them perfect for modern attention spans.
# Global cricket icons like Virat Kohli, Rohit Sharma, and David Warner clash,
# showcasing their skills in a condensed format.
# Beyond the on-field action,
# the IPL thrives on its entertainment value.
# Cheerleaders, Bollywood celebrities,
# and extravagant opening ceremonies add to the spectacle.
# It's not just cricket;
# it's a cultural phenomenon, attracting millions of viewers and fueling a
# multi-billion dollar industry.
# The economic impact is undeniable.
# The IPL contributes significantly to India's GDP, generates jobs, and fuels
# the growth of other sports leagues.
# It's a breeding ground for young talent,
# providing them with a platform to shine and potentially reach the international
# stage.
# However, the IPL isn't without its challenges.
# Concerns about match-fixing,
# player fatigue, and franchise ownership remain.
# Despite these, the IPL's
# popularity shows no signs of waning.
# Its ability to blend sport, entertainment,
# and commerce makes it a powerful force, not just in India, but on the global sporting stage.

# %%
# stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# printing all the stopwords in the library
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Stemming process
from nltk.stem import PorterStemmer
stems = PorterStemmer().stem

# %%
# loop to word tokenize and stem by exluding stop words from document

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [stems(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

sentences
# Out:
# ['the ipl twenty20 cricket leagu , popular world , featur ten city-bas franchis battl annual india .',
#  'found 2007 , quickli rose fame fast-pac action , star-stud player , glamor atmosphere.match short explos , last three hour , make perfect modern attent span .',
#  'global cricket icon like virat kohli , rohit sharma , david warner clash , showcas skill condens format .',
#  'beyond on-field action , ipl thrive entertain valu .',
#  'cheerlead , bollywood celebr , extravag open ceremoni add spectacl .',
#  "it 's cricket ; 's cultur phenomenon , attract million viewer fuel multi-billion dollar industri .",
#  'the econom impact undeni .',
#  "the ipl contribut significantli india 's gdp , gener job , fuel growth sport leagu .",
#  "it 's breed ground young talent , provid platform shine potenti reach intern stage .",
#  "howev , ipl n't without challeng .",
#  'concern match-fix , player fatigu , franchis ownership remain .',
#  "despit , ipl' popular show sign wane .",
#  'it abil blend sport , entertain , commerc make power forc , india , global sport stage .']

# %%
# Snowball stemming
sentences = nltk.sent_tokenize(corpus)
from nltk.stem import SnowballStemmer
sbstems = SnowballStemmer('english').stem

# %%
# loop to word tokenize and stem by exluding stop words from document

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [sbstems(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

sentences
# Out:
# ['the ipl twenty20 cricket leagu , popular world , featur ten city-bas franchis battl annual india .',
#  'found 2007 , quick rose fame fast-pac action , star-stud player , glamor atmosphere.match short explos , last three hour , make perfect modern attent span .',
#  'global cricket icon like virat koh , rohit sharma , david warner clash , showcas skill condens format .',
#  'beyond on-field action , ipl thrive entertain valu .',
#  'cheerlead , bollywood celebr , extravag open ceremoni add spectacl .',
#  "it 's cricket ; 's cultur phenomenon , attract million viewer fuel multi-billion dollar industri .",
#  'the econom impact undeni .',
#  "the ipl contribut signific india 's gdp , generat job , fuel growth sport leagu .",
#  "it 's breed ground young talent , provid platform shine potenti reach intern stage .",
#  "howev , ipl n't without challeng .",
#  'concern match-fix , player fatigu , franchis ownership remain .',
#  'despit , ipl popular show sign wane .',
#  'it abil blend sport , entertain , commerc make power forc , india , global sport stage .']

# %%
# Lemmatization
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmas = WordNetLemmatizer().lemmatize
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# loop to word tokenize and lemmatize by exluding the stop words
sentences = nltk.sent_tokenize(corpus)
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [lemmas(word.lower(), pos='v') for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

sentences
# Out:
# ['the ipl twenty20 cricket league , popular world , feature ten city-based franchise battle annually india .',
#  'found 2007 , quickly rise fame fast-paced action , star-studded players , glamorous atmosphere.matches short explosive , last three hours , make perfect modern attention span .',
#  'global cricket icons like virat kohli , rohit sharma , david warner clash , showcasing skills condense format .',
#  'beyond on-field action , ipl thrive entertainment value .',
#  'cheerleaders , bollywood celebrities , extravagant open ceremonies add spectacle .',
#  "it 's cricket ; 's cultural phenomenon , attract millions viewers fuel multi-billion dollar industry .",
#  'the economic impact undeniable .',
#  "the ipl contribute significantly india 's gdp , generate job , fuel growth sport league .",
#  "it 's breed grind young talent , provide platform shine potentially reach international stage .",
#  "however , ipl n't without challenge .",
#  'concern match-fixing , player fatigue , franchise ownership remain .',
#  "despite , ipl's popularity show sign wan .",
#  'its ability blend sport , entertainment , commerce make powerful force , india , global sport stage .']

# %% [markdown]
# POS - Parts Of Speech

# %%
print(corpus)
# Out:
# The IPL is a Twenty20 cricket league, the most popular in the world,
# featuring ten city-based franchises battling it out annually in India.
# Founded in 2007, it quickly rose to fame with its fast-paced action,
# star-studded players, and glamorous atmosphere.Matches are short and explosive,
# lasting just three hours, making them perfect for modern attention spans.
# Global cricket icons like Virat Kohli, Rohit Sharma, and David Warner clash,
# showcasing their skills in a condensed format. Beyond the on-field action,
# the IPL thrives on its entertainment value. Cheerleaders, Bollywood celebrities,
# and extravagant opening ceremonies add to the spectacle. It's not just cricket;
# it's a cultural phenomenon, attracting millions of viewers and fueling a
# multi-billion dollar industry. The economic impact is undeniable.
# The IPL contributes significantly to India's GDP, generates jobs, and fuels
# the growth of other sports leagues. It's a breeding ground for young talent,
# providing them with a platform to shine and potentially reach the international
# stage. However, the IPL isn't without its challenges. Concerns about match-fixing,
# player fatigue, and franchise ownership remain. Despite these, the IPL's
# popularity shows no signs of waning. Its ability to blend sport, entertainment,
# and commerce makes it a powerful force, not just in India, but on the global sporting stage.

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# loop to word tokenize and get pos
sentences = nltk.sent_tokenize(corpus)
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word.lower() for word in words if word not in set(stopwords.words('english'))]
    tags = nltk.pos_tag(words)
    print(tags)
# Out:
# [('the', 'DT'), ('ipl', 'NN'), ('twenty20', 'NN'), ('cricket', 'NN'), ('league', 'NN'), (',', ','), ('popular', 'JJ'), ('world', 'NN'), (',', ','), ('featuring', 'VBG'), ('ten', 'JJ'), ('city-based', 'JJ'), ('franchises', 'NNS'), ('battling', 'VBG'), ('annually', 'RB'), ('india', 'RB'), ('.', '.')]
# [('founded', 'JJ'), ('2007', 'CD'), (',', ','), ('quickly', 'RB'), ('rose', 'VBD'), ('fame', 'JJ'), ('fast-paced', 'JJ'), ('action', 'NN'), (',', ','), ('star-studded', 'JJ'), ('players', 'NNS'), (',', ','), ('glamorous', 'JJ'), ('atmosphere.matches', 'NNS'), ('short', 'JJ'), ('explosive', 'JJ'), (',', ','), ('lasting', 'JJ'), ('three', 'CD'), ('hours', 'NNS'), (',', ','), ('making', 'VBG'), ('perfect', 'JJ'), ('modern', 'JJ'), ('attention', 'NN'), ('spans', 'NNS'), ('.', '.')]
# [('global', 'JJ'), ('cricket', 'NN'), ('icons', 'NNS'), ('like', 'IN'), ('virat', 'NN'), ('kohli', 'NN'), (',', ','), ('rohit', 'VB'), ('sharma', 'NN'), (',', ','), ('david', 'JJ'), ('warner', 'NN'), ('clash', 'NN'), (',', ','), ('showcasing', 'VBG'), ('skills', 'NNS'), ('condensed', 'VBN'), ('format', 'NN'), ('.', '.')]
# [('beyond', 'IN'), ('on-field', 'JJ'), ('action', 'NN'), (',', ','), ('ipl', 'NN'), ('thrives', 'NNS'), ('entertainment', 'NN'), ('value', 'NN'), ('.', '.')]
# [('cheerleaders', 'NNS'), (',', ','), ('bollywood', 'NN'), ('celebrities', 'NNS'), (',', ','), ('extravagant', 'JJ'), ('opening', 'NN'), ('ceremonies', 'NNS'), ('add', 'VBP'), ('spectacle', 'NN'), ('.', '.')]
# [('it', 'PRP'), ("'s", 'VBZ'), ('cricket', 'NN'), (';', ':'), ("'s", 'POS'), ('cultural', 'JJ'), ('phenomenon', 'NN'), (',', ','), ('attracting', 'VBG'), ('millions', 'NNS'), ('viewers', 'NNS'), ('fueling', 'VBG'), ('multi-billion', 'JJ'), ('dollar', 'NN'), ('industry', 'NN'), ('.', '.')]
# [('the', 'DT'), ('economic', 'JJ'), ('impact', 'NN'), ('undeniable', 'JJ'), ('.', '.')]
# [('the', 'DT'), ('ipl', 'NN'), ('contributes', 'VBZ'), ('significantly', 'RB'), ('india', 'VBP'), ("'s", 'POS'), ('gdp', 'NN'), (',', ','), ('generates', 'VBZ'), ('jobs', 'NNS'), (',', ','), ('fuels', 'NNS'), ('growth', 'NN'), ('sports', 'NNS'), ('leagues', 'NNS'), ('.', '.')]
# [('it', 'PRP'), ("'s", 'VBZ'), ('breeding', 'VBG'), ('ground', 'NN'), ('young', 'JJ'), ('talent', 'NN'), (',', ','), ('providing', 'VBG'), ('platform', 'NN'), ('shine', 'NN'), ('potentially', 'RB'), ('reach', 'VBP'), ('international', 'JJ'), ('stage', 'NN'), ('.', '.')]
# [('however', 'RB'), (',', ','), ('ipl', 'VBP'), ("n't", 'RB'), ('without', 'IN'), ('challenges', 'NNS'), ('.', '.')]
# [('concerns', 'NNS'), ('match-fixing', 'NN'), (',', ','), ('player', 'NN'), ('fatigue', 'NN'), (',', ','), ('franchise', 'NN'), ('ownership', 'NN'), ('remain', 'VBP'), ('.', '.')]
# [('despite', 'IN'), (',', ','), ("ipl's", 'JJ'), ('popularity', 'NN'), ('shows', 'VBZ'), ('signs', 'NNS'), ('waning', 'VBG'), ('.', '.')]
# [('its', 'PRP$'), ('ability', 'NN'), ('blend', 'NN'), ('sport', 'NN'), (',', ','), ('entertainment', 'NN'), (',', ','), ('commerce', 'NN'), ('makes', 'VBZ'), ('powerful', 'JJ'), ('force', 'NN'), (',', ','), ('india', 'NN'), (',', ','), ('global', 'JJ'), ('sporting', 'NN'), ('stage', 'NN'), ('.', '.')]

# %%
print(nltk.pos_tag('This is Natural Language Processing class by Suresh'.split()))
# Out:
# [('This', 'DT'), ('is', 'VBZ'), ('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('class', 'NN'), ('by', 'IN'), ('Suresh', 'NNP')]
